# %%
import numpy as np 
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
data = pl.DataFrame({
    
})

# %%
import numpy as np 
import polars as pl

data = pl.DataFrame({
    "a": [1, 2, 3],
    "b": [4, 5, 6]
})
print(data)
# Out:
# shape: (3, 2)
# ┌─────┬─────┐
# │ a   ┆ b   │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 1   ┆ 4   │
# │ 2   ┆ 5   │
# │ 3   ┆ 6   │
# └─────┴─────┘
